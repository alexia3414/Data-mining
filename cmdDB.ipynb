# %% [markdown]
# EXTRACT DATA

# %%
import pandas as pd

# %%
df= pd.read_excel("financial_sample.xlsx")
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %% [markdown]
# SELECT FEW COLUMS

# %%
Date = df[['Month Number','Month Name','Year']]
Date
# Out:
#      Month Number Month Name  Year
# 0               1    January  2014
# 1               1    January  2014
# 2               6       June  2014
# 3               6       June  2014
# 4               6       June  2014
# ..            ...        ...   ...
# 695             3      March  2014
# 696            10    October  2014
# 697             2   February  2014
# 698             4      April  2014
# 699             5        May  2014
#
# [700 rows x 3 columns]

# %%
Date = Date.rename(columns={'Month Number':'d_day','Month Name':'d_month','Year':'d_year'})
Date
# Out:
#      d_date   d_month  d_year
# 0         1   January    2014
# 1         1   January    2014
# 2         6      June    2014
# 3         6      June    2014
# 4         6      June    2014
# ..      ...       ...     ...
# 695       3     March    2014
# 696      10   October    2014
# 697       2  February    2014
# 698       4     April    2014
# 699       5       May    2014
#
# [700 rows x 3 columns]

# %%
df1= pd.read_excel("Electric_Vehicle_Population_Data.xlsx")
df1
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 1       JHMZC5F37M    Kitsap        Poulsbo    WA      98370.0        2021
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 3       1N4AZ0CP5D      King        Seattle    WA      98119.0        2013
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# ...            ...       ...            ...   ...          ...         ...
# 130438  7SAYGDEE6P    Pierce     Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N    Pierce         Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M      King        Seattle    WA      98109.0        2021
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
# 130442  5YJ3E1EA5M    Pierce       Puyallup    WA      98375.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# ...

# %%
df = df1[['Electric Vehicle Type','Model']]
df
# Out:
#                          Electric Vehicle Type    Model
# 0               Battery Electric Vehicle (BEV)  MODEL X
# 1       Plug-in Hybrid Electric Vehicle (PHEV)  CLARITY
# 2               Battery Electric Vehicle (BEV)  MODEL 3
# 3               Battery Electric Vehicle (BEV)     LEAF
# 4               Battery Electric Vehicle (BEV)  MODEL S
# ...                                        ...      ...
# 130438          Battery Electric Vehicle (BEV)  MODEL Y
# 130439          Battery Electric Vehicle (BEV)     LEAF
# 130440          Battery Electric Vehicle (BEV)  MODEL Y
# 130441          Battery Electric Vehicle (BEV)  MODEL X
# 130442          Battery Electric Vehicle (BEV)  MODEL 3
#
# [130443 rows x 2 columns]

# %%
product= df1[['Electric Vehicle Type','Model']]
product = product.rename(columns={'Electric Vehicle Type':'Product_Name','Model':'Category'})
product
# Out:
#                                   Product_Name Category
# 0               Battery Electric Vehicle (BEV)  MODEL X
# 1       Plug-in Hybrid Electric Vehicle (PHEV)  CLARITY
# 2               Battery Electric Vehicle (BEV)  MODEL 3
# 3               Battery Electric Vehicle (BEV)     LEAF
# 4               Battery Electric Vehicle (BEV)  MODEL S
# ...                                        ...      ...
# 130438          Battery Electric Vehicle (BEV)  MODEL Y
# 130439          Battery Electric Vehicle (BEV)     LEAF
# 130440          Battery Electric Vehicle (BEV)  MODEL Y
# 130441          Battery Electric Vehicle (BEV)  MODEL X
# 130442          Battery Electric Vehicle (BEV)  MODEL 3
#
# [130443 rows x 2 columns]

# %%
customer = df[['Segment','Country',]]
customer = customer.rename(columns={'Segment':'customer_name', 'Country':'City'})
customer
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 customer = df[['Segment','Country',]]
#       2 customer = customer.rename(columns={'Segment':'customer_name', 'Country':'City'})
#       3 customer
#
# File C:\Program Files\anaconda\1\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File C:\Program Files\anaconda\1\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root",database="etl_db")

# %%
cursor = mydb.cursor()

# %%
date = Date.fillna('')
Date
# Out:
#      d_date   d_month  d_year
# 0         1   January    2014
# 1         1   January    2014
# 2         6      June    2014
# 3         6      June    2014
# 4         6      June    2014
# ..      ...       ...     ...
# 695       3     March    2014
# 696      10   October    2014
# 697       2  February    2014
# 698       4     April    2014
# 699       5       May    2014
#
# [700 rows x 3 columns]

# %%
insert_query = f"INSERT INTO date_tb ({','.join(Date.columns)}) VALUES ({','.join(['%s']*len(Date.columns))})"
    
for _, row in Date.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[88], line 5
#       3 for _, row in Date.iterrows():
#       4     values = tuple(row)
# ----> 5     cursor.execute(insert_query, values)
#       7 mydb.commit()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\cursor.py:416, in MySQLCursor.execute(self, operation, params, map_results)
#     408 self._executed_list = self._stmt_partition["single_stmts"]
#     409 self._executed = (
#     410     self._stmt_partition["single_stmts"].popleft()
#     411     if map_results
#     412     else self._stmt_partition["mappable_stmt"]
#     413 )
#     415 self._handle_result(
# --> 416     self._connection.cmd_query(
#     417         self._stmt_partition["mappable_stmt"],
#     418         read_timeout=self._read_timeout,
#     419         write_timeout=self._write_timeout,
#     420     )
#     421 )
# ...
